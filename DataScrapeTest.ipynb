# %%
import requests
import pandas as pd
from difflib import get_close_matches
import json

# %%
season_id = '2007-08'
season_start = 51
season_end = 95

# %%
player_info_url = 'https://stats.nba.com/stats/leagueLeaders?LeagueID=00&PerMode=PerGame&Scope=S&Season='+ season_id + '&SeasonType=Regular+Season&StatCategory=PTS'

# %%
headers = {
    'Connection': 'keep-alive',
    'Accept': 'application/json, text/plain, */*',
    'x-nba-stats-token': 'true',
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36',
    'x-nba-stats-origin': 'stats',
    'Sec-Fetch-Site': 'same-origin',
    'Sec-Fetch-Mode': 'cors',
    'Referer': 'https://stats.nba.com/',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'en-US,en;q=0.9',
}

# %%
response = requests.get(url=player_info_url, headers=headers).json()
response
# Out:
# {'resource': 'leagueleaders',
#  'parameters': {'LeagueID': '00',
#   'PerMode': 'PerGame',
#   'StatCategory': 'PTS',
#   'Season': '2007-08',
#   'SeasonType': 'Regular Season',
#   'Scope': 'S',
#   'ActiveFlag': None},
#  'resultSet': {'name': 'LeagueLeaders',
#   'headers': ['PLAYER_ID',
#    'RANK',
#    'PLAYER',
#    'TEAM',
#    'GP',
#    'MIN',
#    'FGM',
#    'FGA',
#    'FG_PCT',
#    'FG3M',
#    'FG3A',
#    'FG3_PCT',
#    'FTM',
#    'FTA',
#    'FT_PCT',
#    'OREB',
#    'DREB',
#    'REB',
#    'AST',
#    'STL',
#    'BLK',
#    'TOV',
#    'PTS',
#    'EFF'],
#   'rowSet': [[2544,
#     1,
#     'LeBron James',
#     'CLE',
#     75,
#     40.4,
#     10.6,
#     21.9,
#     0.484,
#     1.5,
#     4.8,
#     0.315,
#     7.3,
#     10.3,
#     0.712,
#     1.8,
#     6.1,
#     7.9,
#     7.2,
#     1.8,
#     1.1,
#     3.4,
#     30.0,
#     30.3],
#    [977,
#     2,
#     'Kobe Bryant',
#     'LAL',
#     82,
#     38.9,
#     9.5,
#     20.6,
# ...

# %%
player_info = response['resultSet']['rowSet']
player_info
# Out:
# [[2544,
#   1,
#   'LeBron James',
#   'CLE',
#   75,
#   40.4,
#   10.6,
#   21.9,
#   0.484,
#   1.5,
#   4.8,
#   0.315,
#   7.3,
#   10.3,
#   0.712,
#   1.8,
#   6.1,
#   7.9,
#   7.2,
#   1.8,
#   1.1,
#   3.4,
#   30.0,
#   30.3],
#  [977,
#   2,
#   'Kobe Bryant',
#   'LAL',
#   82,
#   38.9,
#   9.5,
#   20.6,
#   0.459,
#   1.8,
#   5.1,
#   0.361,
#   7.6,
#   9.0,
#   0.84,
#   1.1,
#   5.2,
#   6.3,
#   5.4,
#   1.8,
#   0.5,
#   3.1,
#   28.3,
#   26.6],
#  [947,
#   3,
#   'Allen Iverson',
#   'DEN',
#   82,
#   41.8,
#   8.7,
#   19.0,
#   0.458,
#   1.2,
#   3.4,
#   0.345,
#   7.9,
#   9.7,
#   0.809,
#   0.6,
#   2.4,
#   3.0,
#   7.1,
#   2.0,
#   0.1,
#   3.0,
#   26.4,
#   23.5],
#  [2546,
#   4,
#   'Carmelo Anthony',
#   'DEN',
#   77,
#   36.4,
#   9.5,
#   19.2,
#   0.492,
#   0.8,
#   2.1,
#   0.354,
#   6.0,
#   7.7,
#   0.786,
#   2.3,
#   5.1,
#   7.4,
#   3.4,
#   1.3,
#   0.5,
#   3.3,
#   25.7,
#   23.5],
#  [2405,
#   5,
#   "Amar'e Stoudemire",
# ...

# %%
column_headers = [
   'PLAYER_ID',
   'RANK',
   'PLAYER',
   'TEAM',
   'GP',
   'MIN',
   'FGM',
   'FGA',
   'FG_PCT',
   'FG3M',
   'FG3A',
   'FG3_PCT',
   'FTM',
   'FTA',
   'FT_PCT',
   'OREB',
   'DREB',
   'REB',
   'AST',
   'STL',
   'BLK',
   'TOV',
   'PTS',
   'EFF'
]

# %%
nba_df = pd.DataFrame(player_info, columns=column_headers)
nba_df['player_namelower'] = nba_df['PLAYER'].str.lower()

# %%
nba_df.head()
# Out:
#    PLAYER_ID  RANK             PLAYER TEAM  GP   MIN   FGM   FGA  FG_PCT  \
# 0       2544     1       LeBron James  CLE  75  40.4  10.6  21.9   0.484
# 1        977     2        Kobe Bryant  LAL  82  38.9   9.5  20.6   0.459
# 2        947     3      Allen Iverson  DEN  82  41.8   8.7  19.0   0.458
# 3       2546     4    Carmelo Anthony  DEN  77  36.4   9.5  19.2   0.492
# 4       2405     5  Amar'e Stoudemire  PHX  79  33.9   9.0  15.3   0.590
#
#    FG3M  ...  OREB  DREB  REB  AST  STL  BLK  TOV   PTS   EFF  \
# 0   1.5  ...   1.8   6.1  7.9  7.2  1.8  1.1  3.4  30.0  30.3
# 1   1.8  ...   1.1   5.2  6.3  5.4  1.8  0.5  3.1  28.3  26.6
# 2   1.2  ...   0.6   2.4  3.0  7.1  2.0  0.1  3.0  26.4  23.5
# 3   0.8  ...   2.3   5.1  7.4  3.4  1.3  0.5  3.3  25.7  23.5
# 4   0.1  ...   2.3   6.8  9.1  1.5  0.8  2.1  2.2  25.2  28.4
#
#     player_namelower
# 0       lebron james
# 1        kobe bryant
# 2      allen iverson
# 3    carmelo anthony
# 4  amar'e stoudemire
#
# ...

# %%
filt_nba_df = nba_df.loc[(nba_df['player_namelower'] == "shaquille o'neal")]
filt_nba_df
#exists = "chris webber" in nba_df['player_namelower'].values
#print(exists)
# Out:
# Empty DataFrame
# Columns: [PLAYER_ID, RANK, PLAYER, TEAM, GP, MIN, FGM, FGA, FG_PCT, FG3M, FG3A, FG3_PCT, FTM, FTA, FT_PCT, OREB, DREB, REB, AST, STL, BLK, TOV, PTS, EFF, player_namelower]
# Index: []
#
# [0 rows x 25 columns]

# %%
#print('kevin durant' in nba_df['player_namelower'].values)
#playerid = nba_df['player_id']['lebron james'].values
#print(playerid)

playeridarr = nba_df.loc[nba_df['player_namelower'] == 'michael jordan', 'PLAYER_ID'].values
print(playeridarr)
# Out:
# []

# %%
# Out:
#      PLAYER_ID  RANK             PLAYER TEAM  GP   MIN   FGM   FGA  FG_PCT  \
# 0         2544     1       LeBron James  CLE  75  40.4  10.6  21.9   0.484
# 1          977     2        Kobe Bryant  LAL  82  38.9   9.5  20.6   0.459
# 2          947     3      Allen Iverson  DEN  82  41.8   8.7  19.0   0.458
# 3         2546     4    Carmelo Anthony  DEN  77  36.4   9.5  19.2   0.492
# 4         2405     5  Amar'e Stoudemire  PHX  79  33.9   9.0  15.3   0.590
# ..         ...   ...                ...  ...  ..   ...   ...   ...     ...
# 196     200771   197   Sergio Rodriguez  POR  72   8.7   1.0   2.7   0.352
# 197       1502   198       Adonal Foyle  ORL  82   9.4   0.9   1.9   0.458
# 198       2215   199      Jason Collins  MEM  74  15.8   0.7   1.5   0.469
# 199       2260   200     Jarron Collins  UTA  70  10.0   0.5   1.2   0.439
# 200     201187   201    Dominic McGuire  WAS  70   9.9   0.6   1.5   0.379
#
#      FG3M  ...  OREB  DREB  REB  AST  STL  BLK  TOV   PTS   EFF  \
# ...

# %% [markdown]
# ###
